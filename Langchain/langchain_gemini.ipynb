# %%
import langchain_google_genai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
import os

# %%
api = os.getenv("gemini_api")

# %%
model = ChatGoogleGenerativeAI(api_key=api, model="gemini-2.0-flash")

# %%
response = model.invoke("Hi")
print(response.content)
again = model.invoke("Do you remember the previous prompt i gave you?")
print(again.content)
# Out:
# Hi there! How can I help you today?
# As a large language model, I don't have memory of past conversations. Each interaction I have with you is a new one. So, no, I don't remember the previous prompt you gave me.
