# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# %%
load_dotenv()
key = os.getenv("test_api")

llm = ChatOpenAI(api_key=key, model="gpt-3.5-turbo")

# %%
response = llm.invoke("Hi")
